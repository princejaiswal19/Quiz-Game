# %% [markdown]
# <a href="https://colab.research.google.com/github/princejaiswal19/Quiz-Game/blob/main/project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 3)

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
 import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
 x_train
# Out:
#     cgpa     iq
# 79   6.5   90.0
# 21   7.1  151.0
# 28   5.2   90.0
# 66   6.9   96.0
# 2    5.3  121.0
# ..   ...    ...
# 24   4.7  121.0
# 90   7.3   86.0
# 40   4.9  134.0
# 48   6.6  138.0
# 76   4.9  155.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 8    6.1  156.0
# 6    5.7  143.0
# 86   5.1  128.0
# 9    5.1   66.0
# 81   5.4  107.0
# 43   6.8  141.0
# 45   6.0   66.0
# 97   6.7  182.0
# 10   6.0   45.0
# 85   5.8  166.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 4.18425524e-01, -8.68028857e-01],
#        [ 9.25039388e-01,  6.90335572e-01],
#        [-6.79237847e-01, -8.68028857e-01],
#        [ 7.56168100e-01, -7.14747110e-01],
#        [-5.94802203e-01, -7.60731634e-02],
#        [-6.79237847e-01,  2.55526350e+00],
#        [-2.57059627e-01,  4.09319036e-01],
#        [-1.35472300e+00, -2.09428283e+00],
#        [ 1.26278196e+00, -1.60889063e+00],
#        [ 1.34721761e+00,  1.02755542e-01],
#        [ 6.71732456e-01, -3.05995784e-01],
#        [ 8.06829486e-02,  2.04943373e-01],
#        [ 1.76939583e+00,  1.07353994e+00],
#        [ 6.71732456e-01, -2.49792477e-02],
#        [-9.32544779e-01,  6.90335572e-01],
#        [-2.57059627e-01,  2.04943373e-01],
#        [ 1.09391068e+00, -1.88990717e+00],
#        [-6.79237847e-01,  2.04943373e-01],
#        [-1.35472300e+00,  6.39241657e-01],
#        [ 2.10713840e+00, -1.01620121e-01],
#        [-5.10366559e-01, -2.54901868e-01],
#        [ 8.40603744e-01, -3.05995784e-01],
# ...

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.08068295,  0.81807036],
#        [-0.25705963,  0.48595991],
#        [-0.76367349,  0.10275554],
#        [-0.76367349, -1.48115585],
#        [-0.51036656, -0.43373057],
#        [ 0.67173246,  0.43486599],
#        [-0.0037527 , -1.48115585],
#        [ 0.58729681,  1.48229127],
#        [-0.0037527 , -2.01764196],
#        [-0.17262398,  1.07353994]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
cif=LogisticRegression()

# %%
cif.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=cif.predict(x_test)

# %%
y_test
# Out:
# 8     0
# 6     0
# 86    0
# 9     0
# 81    0
# 43    1
# 45    1
# 97    1
# 10    1
# 85    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=cif,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(cif,open('model.pkl','wb'))
